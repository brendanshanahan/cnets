# %%
from graphs.graphs import *
import simulations.simulations
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import importlib

# %%
c = GraphClone(nx.cycle_graph(20))

importlib.reload(simulations.simulations)
# Out:
# <module 'simulations.simulations' from '/home/jimmy/Masters_2019/graphProj/simulations/simulations.py'>

# %%
for i in range(10):
    for j in range(10):
        c.add_edge(i,j)

for i in range(10, 20):
    for j in range(10,20):
        c.add_edge(i,j)

# %%
t = simulations.simulations.SimObject(c)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Relaxation: :   0%|          | 0/2000 [00:00<?, ?it/s]
# Relaxation: : 100%|██████████| 2000/2000 [00:00<00:00, 30679.96it/s]

# %%
t.highlight_clusters()
