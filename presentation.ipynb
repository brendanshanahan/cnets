# %%
from graphs.graphs import *
from simulations.simulations import *
import simulations.simulations
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import importlib
importlib.reload(simulations.simulations)

c = GraphClone(nx.cycle_graph(20))
draw_graph(c)

# %%
wave_equation(c, 200)
plt.figure(figsize=(20,10))
plt.plot(c.state)
plt.show()
# Out:
# Relaxation: : 100%|███████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 20055.97it/s]

# %%
plot_fft(c)

# %%
for i in range(10):
    for j in range(10):
        c.add_edge(i,j)

for i in range(10, 20):
    for j in range(10,20):
        c.add_edge(i,j)

draw_graph(c)

# %%
wave_equation(c, 2000)
plt.figure(figsize=(20,10))
plt.plot(c.state)
plt.show()
# Out:
# Relaxation: : 100%|█████████████████████████████████████████████████████████████| 2000/2000 [00:00<00:00, 30851.70it/s]

# %%
plot_fft(c)

# %%
fft = np.fft.fft(c.state, axis=0)
ctr = (int)(len(fft)/2)
fft = np.append(fft[ctr:, :], fft[:ctr, :], axis=0)
plt.figure(figsize=(20, 10))
plt.plot(fft)
plt.show()
# Out:
# C:\Users\Jimmy\Anaconda3\lib\site-packages\numpy\core\numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
importlib.reload(simulations.simulations)
simulations.simulations.highlight_clusters(c, simulations.simulations.fft_peaks(c))

# %%
c = GraphClone(nx.cycle_graph(20))

for i in range(6):
    for j in range(6):
        c.add_edge(i,j)

for i in range(6, 20):
    for j in range(6,20):
        c.add_edge(i,j)

draw_graph(c)

# %%
wave_equation(c, 2000)
# Out:
# Relaxation: : 100%|█████████████████████████████████████████████████████████████| 2000/2000 [00:00<00:00, 31327.19it/s]

# %%
plot_fft(c)

# %%
simulations.simulations.highlight_clusters(c, simulations.simulations.fft_peaks(c))

# %%
c = SmallWorldGraph(500, 5, 0.3)
c = GraphClone(c)
draw_graph(c)

# %%
wave_equation(c, 2000)
# Out:
# Relaxation: : 100%|███████████████████████████████████████████████████████████████| 2000/2000 [00:10<00:00, 184.11it/s]

# %%
plot_fft(c)

# %%
simulations.simulations.highlight_clusters(c, fft_peaks(c))
